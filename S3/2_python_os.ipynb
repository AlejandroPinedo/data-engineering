# %%
import os
import shutil

# %%
# Get current directory
print(os.getcwd())
# Out:
# /content

# %%
# List directories
os.listdir()
# Out:
# ['.config', 'sample_data']

# %%
# Join paths
os.path.join(os.getcwd(), 'requirements.txt')
# Out:
# '/content/requirements.txt'

# %%
# Make DIRECTORY
os.mkdir('test.py')

# %%
# Make DIRECTORIES
os.makedirs('test1/test2')

# %%
# Renaming a DIRECTORY / FILES
os.rename('test.py', 'test')

# %%
# Check if path exists
os.path.exists('test')
# Out:
# True

# %%
# Getting absolute path
os.path.abspath('test')
# Out:
# '/content/test'

# %%
# Creating a FILE
open('test.csv', 'a').close()

# %%
open('test_1.csv', 'a').close()

# %%
print(os.listdir())
# Out:
# ['.config', 'test', 'test1', 'test.csv', 'test_1.csv', 'sample_data']

# %%
# Is FILE?
os.path.isfile('test')
# Out:
# False

# %%
os.path.isfile('test.csv')
# Out:
# True

# %%
# Is DIRECTORY?
os.path.isdir('test')
# Out:
# True

# %%
os.path.isdir('test.csv')
# Out:
# False

# %%
# Moving FILES / DIRECTORIES
file_path = 'test_1.csv'
target_path = 'test'
shutil.move(file_path, target_path)
# Out:
# 'test/test_1.csv'

# %%
# Removing FILES
os.remove('test.csv')
os.remove('test/test_1.csv')

# %%
# Removing EMPTY DIRECTORIES
os.rmdir('test')

# %%
os.rmdir('test1/test2')

# %%
os.rmdir('test1')

# %%
os.makedirs('test1/test2')

# %%
os.rmdir('test1')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# /tmp/ipykernel_5023/2850436885.py in <cell line: 0>()
# ----> 1 os.rmdir('test1')
#
# OSError: [Errno 39] Directory not empty: 'test1'

# %%
# Removing DIRECTORIES recursively
import shutil
shutil.rmtree('test1')
